# %%
##################################
### Import the usual libraries ###
##################################

### Numpy
import numpy as np

### Astropy
import astropy

#Astropy FITS/Table handling
from astropy.io import fits, ascii
from astropy.table import Table, Column

#astropy coorindates/units
from astropy.coordinates import SkyCoord
import astropy.constants as const
import astropy.units as u

### Pandas
import pandas as pd

### fitting
import statsmodels.api as sm

### PCA
from sklearn.decomposition import PCA, KernelPCA

### Model generation
import itertools as it

### Matplotlib
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.rcParams.update({'font.size': 18}) #make plots more readable

# ### Yumi's RA/DEC ---> Magellanic Stream Coorindates
import MagellanicStream as ms

# ### Functions used in this code
import age_functions as afunc

### Stuff Writtten by A Really Cool Professor
# import dlnpyutils as dlpu

### Other
import warnings
warnings.filterwarnings('ignore')

from tqdm import tqdm_notebook

### Age of Universe
H0 = 74.03*(u.km/u.s)/u.Mpc
hertz = H0.to(u.km/u.s/u.pc).to(u.km/u.s/u.km)
tage = (1/hertz).to(u.yr)
ageU = tage.value

# %%
###################
### Import Data ###
###################

# parsec
''' Ages used 8 to 10.1 steps 0.15'''
''' Metallicity used -2.6 to 0.1 steps 0.099'''

parsecall = ascii.read('/Users/joshuapovick/Desktop/Research/parsec/parsec3_3.dat', \
                    format='basic', delimiter='\s')

rgb = np.where(parsecall['label']==3)
parsec = parsecall[rgb]


# r13
smc = fits.getdata('/Users/joshuapovick/Desktop/Research/fits/smc_rgbmembers.r13-l33-58932beta.fits.gz')
cln = np.where((smc['FE_H']>-9999.0)&(smc['AK_TARG']>-100.0)&(smc['LOGG']>=0.0)&
                (smc['M_H_ERR']>-100.0)&(smc['C_FE']>-100.0)&(smc['N_FE']>-100.0))
smc = smc[cln]

distances = fits.getdata('/Users/joshuapovick/Desktop/Research/SMC_Gradients/SMC_Distances/smc_photokinematic_distances.fits',0)

# %%
###############################
### Some Calcuations Needed ###
###############################

# ### Convert RA DEC to MS L B
# c_icrs = SkyCoord(ra=r13['RA']*u.degree, dec=r13['DEC']*u.degree)
# c_ms = c_icrs.transform_to(ms.MagellanicStream)
# ms_lg,ms_bg = c_ms.MSLongitude.degree, c_ms.MSLatitude.degree

# for i in range(len(ms_lg)):
#     if ms_lg[i]-360<-180:
#         ms_lg[i] += 360.0

### Get Solar Fractions
abd = {'C':8.39,'N':7.78,'O':8.66,'Mg':7.53,'Ca':6.31,'S':7.14,'Si':7.51,'Fe':7.45}
keys = list(abd.keys())

sol_2_H = []
for i in keys:
    sol_2_H.append(abd[i]-12.0)
    
sol_xm  = 10**np.asarray(sol_2_H)/sum(10**np.asarray(sol_2_H))

# %%
### Setup 
data = np.array([parsec['logTe'],parsec['Ksmag'],parsec['MH'],parsec['logg']]).T

### Determine Number of factors
pca = PCA(n_components=4).fit(data)#_rescaled)
plt.rcParams["figure.figsize"] = (12,6)

# fig, ax = plt.subplots()

# y = np.cumsum(pca.explained_variance_ratio_)
# xi = np.arange(1, len(pca.explained_variance_ratio_)+1, step=1)

# plt.ylim(0.0,1.1)
# plt.plot(xi, y, marker='o', linestyle='--', color='b')

# plt.xlabel('Number of Components')
# plt.xticks(np.arange(0, 5, step=1)) #change from 0-based array index to 1-based human-readable label
# plt.ylabel('Cumulative variance (%)')
# plt.title('The number of components needed to explain variance')

# plt.axhline(y=0.99, color='r', linestyle='-')
# plt.text(0.5, 0.85, '99% cut-off threshold', color = 'red', fontsize=16)

# ax.grid(axis='x')
# plt.show()

# %%
def find_ages(z1,z2,z3):
    #x1,x2,x3,x12,x13,x23,x1sq,x2sq,x3sq,x2cu,x3cu
    p = [9.38631710e+00,4.57009017e-02,-5.98198867e-02,-2.99642242e+00,1.86921027e-02,-4.51165023e-02,
         1.10829968e-01,-5.93377185e-03,2.51457473e-02,7.98522275e-01,2.26643514e-02,4.00941011e-01]
    age = (p[0]+p[1]*z1+p[2]*z2+p[3]*z3+p[4]*np.multiply(z1,z2)+p[5]*np.multiply(z1,z3)+p[6]*np.multiply(z2,z3)+
           p[7]*(z1**2)+p[8]*(z2**2)+p[9]*(z3**2)+p[10]*(z2**3)+p[11]*(z3**3))
 
    return age

# %% [markdown]
# <font size='48'>
#     <b>
#         CALCULATE AGES
#     </b>
# </font>

# %%
### Uncertainty Functions

def add_noise(quant,quant_err,distribution='normal'):
    '''
    Add noise to data and return new values
    
    Parameters:
    ----------
        quant: 1d array-like data to add noise to
        quant_err: 1d array-like object of errors for quant
        distribution: which distribution to use 'normal', 'poisson', 'uniform'
    
    return: 
    ------
        1d array-like object of data with added noise
    
    '''
    if distribution == 'normal':
        return np.random.normal(quant,quant_err)
    if distribution == 'poisson':
        return quant + np.random.poisson(quant_err)
    if distribution == 'uniform':
        return np.random.uniform(-quant_err+quant,quant+quant_err)

# %%
distances.columns
# Out:
# ColDefs(
#     name = 'APOGEE_ID'; format = '18A'
#     name = 'FIELD'; format = '5A'
#     name = 'DISTANCE'; format = 'D'
#     name = 'DISTANCE_ERR'; format = 'D'
#     name = 'DISTANCE_DIST'; format = '100D'; dim = '(100)'
# )

# %%
age_dist = []

pca_transform = PCA(n_components=3).fit(data)

for i in tqdm_notebook(range(len(smc)),desc='Done?'):
    # temperature
    teff = smc['TEFF'][i]
    teff_err = smc['TEFF_ERR'][i]
    
    # photometry 
    ra = smc['RA'][i]
    dec = smc['DEC'][i]
    ks = smc['K'][i]
    ks_err = smc['K_ERR'][i]
    ak = smc['AK_TARG'][i]
    
    dist = distances['DISTANCE'][i]
    dist_err = distances['DISTANCE_ERR'][i]
    
    # abundances
    mh = smc['M_H'][i]
    mh_err = smc['M_H_ERR'][i]
    cfe = smc['C_FE'][i]
    cfe_err = smc['C_FE_ERR'][i]
    nfe = smc['N_FE'][i]
    nfe_err = smc['N_FE_ERR'][i]
    feh = smc['FE_H'][i]
    feh_err = smc['FE_H_ERR'][i]
    
    # surface gravity
    lgg = smc['LOGG'][i]
    lgg_err = smc['LOGG_ERR'][i]
    
    noise_ages = []
    new = []
    for j in range(100):
       
        # calculate noisy temperature
        teff_new = add_noise(teff,teff_err) 
        lgteff_new = np.log10(teff_new)
    
        # Calculate noisy K magnitude
#         _, _, dist = afunc.LMCdisk_cart(ra,dec)
        
        dist_new = add_noise(dist,dist_err)
    
        ks_new = add_noise(ks,ks_err)
            
        absK_new = afunc.absmag(ks_new,dist_new) - ak
            
        # Calculate noisy Salaris correction
        
        x_C_new = sol_xm[0]*10**(add_noise(cfe,cfe_err)+
                                 add_noise(feh,feh_err)-add_noise(mh,mh_err))
        x_N_new = sol_xm[1]*10**(add_noise(nfe,nfe_err)+
                                 add_noise(feh,feh_err)-add_noise(mh,mh_err))
        
        ffac_new = (x_C_new+x_N_new)/sum(sol_xm[0:2])
        
        mh_new = add_noise(mh,mh_err)
        
        # Calculate noisy surface gravity
        lgg_new = add_noise(lgg,lgg_err)
            
        # calculate noisy age
        new.append(np.array([lgteff_new,absK_new,afunc.sal(mh_new,ffac_new),lgg_new]))
        
    zs = pca_transform.transform(np.asarray(np.squeeze(new)))

    for l in range(len(zs)):
        noise_ages.append(find_ages(zs[l][0],zs[l][1],zs[l][2]))
    
    age_dist.append(noise_ages)

parages = [] 
devs = []
for k in tqdm_notebook(range(len(age_dist))):
    devs.append(afunc.mad(age_dist[k]))
    parages.append(np.median(age_dist[k]))

# %%
plt.hist(parages)
# Out:
# (array([195., 462., 280.,  39.,  11.,   1.,   0.,   0.,   0.,   2.]),
#  array([ 7.61905021,  8.38306267,  9.14707513,  9.91108759, 10.67510006,
#         11.43911252, 12.20312498, 12.96713744, 13.73114991, 14.49516237,
#         15.25917483]),
#  <BarContainer object of 10 artists>)

# %%
print(np.where(parages>=np.log10(10.5*10**9)))
len(np.squeeze(np.where(parages>=np.log10(10.5*10**9))))
# print(np.log10(0.5*10**9))
# plt.hist(parages)#,range=(8,12))
# Out:
# (array([  1,  31,  80,  94, 106, 112, 188, 207, 214, 225, 288, 304, 318,
#        336, 359, 370, 374, 408, 471, 510, 519, 523, 570, 578, 599, 615,
#        620, 623, 673, 688, 733, 742, 749, 774, 791, 796, 874, 888, 889,
#        891, 898, 904, 912, 944, 976, 977, 986]),)
# 47

# %%
### Log(g)
plt.figure(figsize=[12,10])
plt.scatter(10**np.asarray(parages),devs,c=smc['logg'],cmap='nipy_spectral')
plt.colorbar()

plt.axvline(ageU,c='k')
plt.axvline(0.5*10**9,c='blue',ls='--')
plt.axvline(2.0*10**9,c='green',ls='--')
plt.axvline(7.0*10**9,c='orange',ls='--')
plt.axvline(10.5*10**9,c='red',ls='--')

plt.xscale('log')

plt.ylim(top=0.325)
plt.xlim(right=10**12)

plt.title(r'Color as Log(g)')
plt.xlabel(r'Age [Gyr]')
plt.ylabel(r'Error in Log(Age)')

plt.show()

### [Fe/H]
plt.figure(figsize=[12,10])
plt.scatter(10**np.asarray(parages),devs,c=smc['FE_H'],cmap='nipy_spectral')
plt.colorbar()

plt.axvline(ageU,c='k')
plt.axvline(0.5*10**9,c='blue',ls='--')
plt.axvline(2.0*10**9,c='green',ls='--')
plt.axvline(7.0*10**9,c='orange',ls='--')
plt.axvline(10.5*10**9,c='red',ls='--')

plt.xscale('log')

plt.ylim(top=0.325)
plt.xlim(right=10**12)

plt.title(r'Color as [Fe/H]')
plt.xlabel(r'Age [Gyr]')
plt.ylabel(r'Error in Log(Age)')

plt.show()

# %%
nobimodal = np.where((smc['FIELD']!='SMC4')&(smc['FIELD']!='SMC5')&(smc['FIELD']!='SMC6')&(smc['FIELD']!='SMC7'))

np.unique(smc['FIELD'][nobimodal])
# Out:
# chararray(['47TUC', 'N362', 'SMC1', 'SMC2', 'SMC3'], dtype='<U5')

# %%
nobimodal = np.where((smc['FIELD']!='SMC4')&(smc['FIELD']!='SMC5')&(smc['FIELD']!='SMC6')&(smc['FIELD']!='SMC7'))

### Log(g)
plt.figure(figsize=[12,10])
plt.scatter(10**np.asarray(parages)[nobimodal],np.asarray(devs)[nobimodal],c=smc['logg'][nobimodal],
            cmap='nipy_spectral')
plt.colorbar()

plt.axvline(ageU,c='k')
plt.axvline(0.5*10**9,c='blue',ls='--')
plt.axvline(2.0*10**9,c='green',ls='--')
plt.axvline(7.0*10**9,c='orange',ls='--')
plt.axvline(10.5*10**9,c='red',ls='--')

plt.xscale('log')

plt.ylim(top=0.325)
plt.xlim(right=10**12)

plt.title(r'No Bimodality; Color as Log(g)')
plt.xlabel(r'Age [Gyr]')
plt.ylabel(r'Error in Log(Age)')

plt.show()

### [Fe/H]
plt.figure(figsize=[12,10])
plt.scatter(10**np.asarray(parages)[nobimodal],np.asarray(devs)[nobimodal],c=smc['FE_H'][nobimodal],
            cmap='nipy_spectral')
plt.colorbar()

plt.axvline(ageU,c='k')
plt.axvline(0.5*10**9,c='blue',ls='--')
plt.axvline(2.0*10**9,c='green',ls='--')
plt.axvline(7.0*10**9,c='orange',ls='--')
plt.axvline(10.5*10**9,c='red',ls='--')

plt.xscale('log')

plt.ylim(top=0.325)
plt.xlim(right=10**12)

plt.title(r'No Bimodality; Color as [Fe/H]')
plt.xlabel(r'Age [Gyr]')
plt.ylabel(r'Error in Log(Age)')

plt.show()

# %%
plt.figure(figsize=[24,20])
plt.suptitle(r'SMC Ages using Photo-Kinematic Distances',y=0.9375)
plt.subplot(221)

plt.scatter(10**np.asarray(parages),devs,c=smc['logg'],cmap='nipy_spectral')
plt.colorbar()

plt.axvline(ageU,c='k')
plt.axvline(0.5*10**9,c='blue',ls='--')
plt.axvline(2.0*10**9,c='green',ls='--')
plt.axvline(7.0*10**9,c='orange',ls='--')
plt.axvline(10.5*10**9,c='red',ls='--')

plt.xscale('log')

plt.ylim(top=0.325)
plt.xlim(right=10**12)

plt.title(r'Color as Log(g)')
plt.xlabel(r'Age [yr]')
plt.ylabel(r'Error in Log(Age)')

plt.subplot(222)

plt.scatter(10**np.asarray(parages)[nobimodal],np.asarray(devs)[nobimodal],c=smc['logg'][nobimodal],
            cmap='nipy_spectral')
plt.colorbar()

plt.axvline(ageU,c='k')
plt.axvline(0.5*10**9,c='blue',ls='--')
plt.axvline(2.0*10**9,c='green',ls='--')
plt.axvline(7.0*10**9,c='orange',ls='--')
plt.axvline(10.5*10**9,c='red',ls='--')

plt.xscale('log')

plt.ylim(top=0.325)
plt.xlim(right=10**12)

plt.title(r'No Bimodality; Color as Log(g)')
plt.xlabel(r'Age [yr]')
plt.ylabel(r'Error in Log(Age)')

plt.subplot(223)

plt.scatter(10**np.asarray(parages),devs,c=smc['FE_H'],cmap='nipy_spectral')
plt.colorbar()

plt.axvline(ageU,c='k')
plt.axvline(0.5*10**9,c='blue',ls='--')
plt.axvline(2.0*10**9,c='green',ls='--')
plt.axvline(7.0*10**9,c='orange',ls='--')
plt.axvline(10.5*10**9,c='red',ls='--')

plt.xscale('log')

plt.ylim(top=0.325)
plt.xlim(right=10**12)

plt.title(r'Color as Log(g)')
plt.xlabel(r'Age [yr]')
plt.ylabel(r'Error in Log(Age)')

plt.subplot(224)

plt.scatter(10**np.asarray(parages)[nobimodal],np.asarray(devs)[nobimodal],c=smc['FE_H'][nobimodal],
            cmap='nipy_spectral')
plt.colorbar()

plt.axvline(ageU,c='k')
plt.axvline(0.5*10**9,c='blue',ls='--')
plt.axvline(2.0*10**9,c='green',ls='--')
plt.axvline(7.0*10**9,c='orange',ls='--')
plt.axvline(10.5*10**9,c='red',ls='--')

plt.xscale('log')

plt.ylim(top=0.325)
plt.xlim(right=10**12)

plt.title(r'No Bimodality; Color as Log(g)')
plt.xlabel(r'Age [yr]')
plt.ylabel(r'Error in Log(Age)')

plt.savefig('SMC_ages_and_errors.pdf',bbox_inches='tight')

# %%
pwd
# Out:
# '/Users/joshuapovick/Desktop/Research/SMC_Ages'

# %%
cat = Table()
col_id = Column(np.asarray(smc['APOGEE_ID']),name='APOGEE_ID')
col_age = Column(np.asarray(parages),name='AGE')
col_dev = Column(np.asarray(devs),name='AGE_ERR')
col_dist = Column(np.asarray(age_dist),name='DIST')

cat.add_column(col_id)
cat.add_column(col_age)
cat.add_column(col_dev)
cat.add_column(col_dist)

# cat.write('smc_ages_photokinematic.fits',format='fits')#,overwrite=True)
